# %% [raw]
# Read the dataset from the below link
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US
# _Baby_Names/US_Baby_Names_right.csv
#
# Questions:
# 1. Delete unnamed columns
# 2. Show the distribution of male and female
# 3. Show the top 5 most preferred names
# 4. What is the median name occurence in the dataset
# 5. Distribution of male and female born count by states

# %%
import pandas as pd

# %%
baby_names_ds=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv")
#comment above and uncomment below to read the data file from local after downloading
#baby_names=pd.read_csv("US_Baby_Names_right.csv")

# %%
baby_names.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %%
print("After deleting the unnamed column from dataset")
baby_names.drop(baby_names.columns[0],axis=1,inplace=True)
# Out:
# After deleting the unnamed column from dataset

# %%
baby_names.head()
# Out:
#       Id     Name  Year Gender State  Count
# 0  11350     Emma  2004      F    AK     62
# 1  11351  Madison  2004      F    AK     48
# 2  11352   Hannah  2004      F    AK     46
# 3  11353    Grace  2004      F    AK     44
# 4  11354    Emily  2004      F    AK     41

# %%
gender_dist=pd.Categorical(baby_names["Gender"])

# %%
gender_dist=gender_dist.rename_categories(["Female","Male"])

# %%
print("distribution of male and female :\n")
gender_dist.describe()
# Out:
# distribution of male and female :
#             counts     freqs
# categories
# Female      558846  0.549832
# Male        457549  0.450168

# %%
sum_of_count=baby_names.groupby("Name",as_index=False)[["Name","Count"]].sum()

# %%
print("Showing the top 5 most preferred names")
sum_of_count.sort_values(by="Count",ascending=False)[:6]
# Out:
# Showing the top 5 most preferred names
#            Name   Count
# 7198      Jacob  242874
# 5378       Emma  214852
# 12111   Michael  214405
# 5579      Ethan  209277
# 6973   Isabella  204798
# 16746   William  197894

# %%
print("Median of name occurance: ",sum_of_count.median()[0])
# Out:
# Median of name occurance:  49.0

# %%
sum_of_count_by_states=baby_names.groupby(["State","Gender"],as_index=False)[["State","Gender","Count"]].sum()

# %%
print("Below is the distribution of male and female born count by states")
sum_of_count_by_states
# Out:
# Below is the distribution of male and female born count by states
#     State Gender    Count
# 0      AK      F    26250
# 1      AK      M    37399
# 2      AL      F   215308
# 3      AL      M   260114
# 4      AR      F   129712
# 5      AR      M   162947
# 6      AZ      F   368567
# 7      AZ      M   439691
# 8      CA      F  2414063
# 9      CA      M  2670584
# 10     CO      F   260805
# 11     CO      M   313425
# 12     CT      F   141350
# 13     CT      M   171397
# 14     DC      F    35276
# 15     DC      M    47228
# 16     DE      F    31312
# 17     DE      M    41748
# 18     FL      F   915422
# 19     FL      M  1060957
# 20     GA      F   549637
# 21     GA      M   635531
# 22     HI      F    37279
# 23     HI      M    53127
# 24     IA      F   144764
# 25     IA      M   174009
# 26     ID      F    72808
# 27     ID      M    94320
# 28     IL      F   695312
# 29     IL      M   791679
# ..    ...    ...      ...
# 72     OK      F   184967
# ...
